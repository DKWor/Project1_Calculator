# %%
import pandas as pd
#Data acquisition for deta set1
df = pd.read_excel('dataset_3.xlsx')
df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
#Checking missing values
print(df.isnull().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Check for duplicate rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# Length: 390, dtype: bool

# %%
df.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=df, orient='h')
plt.title("Boxplot of All Numeric Columns")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
df1 = pd.read_csv('Cleaned_dataset.csv')
df1
# Out:
#          dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0    2011-01-01       1   0     1   0    False        6           1  0.24
# 1    2011-01-01       1   0     1   1    False        6           1  0.22
# 2    2011-01-01       1   0     1   2    False        6           1  0.22
# 3    2011-01-01       1   0     1   3    False        6           1  0.24
# 4    2011-01-01       1   0     1   4    False        6           1  0.24
# ..          ...     ...  ..   ...  ..      ...      ...         ...   ...
# 605  2011-01-28       1   0     1  11    False        5           3  0.18
# 606  2011-01-28       1   0     1  12    False        5           3  0.18
# 607  2011-01-28       1   0     1  13    False        5           3  0.18
# 608  2011-01-28       1   0     1  14    False        5           3  0.22
# 609  2011-01-28       1   0     1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
#Checking missing values
print(df1.isnull().sum())
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Check for duplicate rows
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# Length: 610, dtype: bool

# %%
df1.dtypes
# Out:
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df1['dteday'] = pd.to_datetime(df1['dteday'])

# %%
df1.dtypes
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
df1.hist(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df1.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
merged_df = pd.concat([df, df1], ignore_index=True)
merged_df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620.0 2011-01-29       1   0     1   1    False        6           1
# 1      621.0 2011-01-29       1   0     1   2    False        6           1
# 2      622.0 2011-01-29       1   0     1   3    False        6           1
# 3      623.0 2011-01-29       1   0     1   4    False        6           1
# 4      624.0 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 995      NaN 2011-01-28       1   0     1  11    False        5           3
# 996      NaN 2011-01-28       1   0     1  12    False        5           3
# 997      NaN 2011-01-28       1   0     1  13    False        5           3
# 998      NaN 2011-01-28       1   0     1  14    False        5           3
# 999      NaN 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
# Check for duplicate rows
merged_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
merged_df.dtypes
# Out:
# instant              float64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
print(merged_df.isnull().sum())
# Out:
# instant       610
# dteday          0
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
merged_df.drop('instant', axis=1, inplace=True)

# %%
merged_df
# Out:
#         dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0   2011-01-29       1   0     1   1    False        6           1  0.22
# 1   2011-01-29       1   0     1   2    False        6           1  0.22
# 2   2011-01-29       1   0     1   3    False        6           1  0.20
# 3   2011-01-29       1   0     1   4    False        6           1  0.16
# 4   2011-01-29       1   0     1   6    False        6           1  0.16
# ..         ...     ...  ..   ...  ..      ...      ...         ...   ...
# 995 2011-01-28       1   0     1  11    False        5           3  0.18
# 996 2011-01-28       1   0     1  12    False        5           3  0.18
# 997 2011-01-28       1   0     1  13    False        5           3  0.18
# 998 2011-01-28       1   0     1  14    False        5           3  0.22
# 999 2011-01-28       1   0     1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in merged_df:
    plt.figure(figsize=(6, 1))
    sns.boxplot(data=df, x=col)
    plt.title(f"Boxplot for {col}")
    plt.show()

# %%
for col in merged_df:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5 * IQR) | (df[col] > Q3 + 1.5 * IQR)]
    print(f"{col} → Outliers found: {len(outliers)}")
# Out:
# dteday → Outliers found: 0
# season → Outliers found: 0
# yr → Outliers found: 0
# mnth → Outliers found: 78
# hr → Outliers found: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 for col in merged_df:
# ----> 2     Q1 = df[col].quantile(0.25)
#       3     Q3 = df[col].quantile(0.75)
#       4     IQR = Q3 - Q1
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:2887, in Series.quantile(self, q, interpolation)
#    2883 # We dispatch to DataFrame so that core.internals only has to worry
#    2884 #  about 2D cases.
#    2885 df = self.to_frame()
# -> 2887 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888 if result.ndim == 2:
#    2889     result = result.iloc[:, 0]
#
# ...

# %%
print(df['mnth'].unique())
# Out:
# [1 2]

# %%
Q1 = df['mnth'].quantile(0.25)
Q3 = df['mnth'].quantile(0.75)
IQR = Q3 - Q1

# Outlier condition
outliers = df[(df['mnth'] < Q1 - 1.5 * IQR) | (df['mnth'] > Q3 + 1.5 * IQR)]
print(outliers[['mnth']])
# Out:
#      mnth
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 385     1
# 386     1
# 387     1
# 388     1
# 389     1
#
# [78 rows x 1 columns]

# %%
merged_df = merged_df[merged_df['mnth'].between(1, 12)]

# %%
merged_df
# Out:
#         dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0   2011-01-29       1   0     1   1    False        6           1  0.22
# 1   2011-01-29       1   0     1   2    False        6           1  0.22
# 2   2011-01-29       1   0     1   3    False        6           1  0.20
# 3   2011-01-29       1   0     1   4    False        6           1  0.16
# 4   2011-01-29       1   0     1   6    False        6           1  0.16
# ..         ...     ...  ..   ...  ..      ...      ...         ...   ...
# 995 2011-01-28       1   0     1  11    False        5           3  0.18
# 996 2011-01-28       1   0     1  12    False        5           3  0.18
# 997 2011-01-28       1   0     1  13    False        5           3  0.18
# 998 2011-01-28       1   0     1  14    False        5           3  0.22
# 999 2011-01-28       1   0     1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
skewness = merged_df.skew(numeric_only=True)
print("Skewness for numeric columns:\n")
print(skewness.sort_values(ascending=False))
# Out:
# Skewness for numeric columns:
#
# holiday       6.229578
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# weathersit    1.044098
# mnth          0.812772
# temp          0.547997
# hum           0.436893
# atemp         0.435927
# windspeed     0.433675
# weekday       0.021925
# season        0.000000
# yr            0.000000
# hr           -0.063524
# dtype: float64

# %%
high_skew = skewness[abs(skewness) > 1]
print("\nHighly skewed columns (|skew| > 1):")
print(high_skew)
# Out:
# Highly skewed columns (|skew| > 1):
# holiday       6.229578
# weathersit    1.044098
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in high_skew.index:
    plt.figure(figsize=(6, 3))
    sns.histplot(merged_df[col], kde=True)
    plt.title(f"Distribution and Skewness: {col}")
    plt.tight_layout()
    plt.show()

# %%
print(merged_df)
# Out:
#         dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0   2011-01-29       1   0     1   1    False        6           1  0.22
# 1   2011-01-29       1   0     1   2    False        6           1  0.22
# 2   2011-01-29       1   0     1   3    False        6           1  0.20
# 3   2011-01-29       1   0     1   4    False        6           1  0.16
# 4   2011-01-29       1   0     1   6    False        6           1  0.16
# ..         ...     ...  ..   ...  ..      ...      ...         ...   ...
# 995 2011-01-28       1   0     1  11    False        5           3  0.18
# 996 2011-01-28       1   0     1  12    False        5           3  0.18
# 997 2011-01-28       1   0     1  13    False        5           3  0.18
# 998 2011-01-28       1   0     1  14    False        5           3  0.22
# 999 2011-01-28       1   0     1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
print(merged_df.dtypes)
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
merged_df['holiday'].unique()
# Out:
# array([False,  True])

# %%
quality_map = {'False': 1, 'True': 2}
merged_df['holiday'] = merged_df['holiday'].map(quality_map)

# %%
print(merged_df.isnull().sum())
# Out:
# dteday           0
# season           0
# yr               0
# mnth             0
# hr               0
# holiday       1000
# weekday          0
# weathersit       0
# temp             0
# atemp            0
# hum              0
# windspeed        0
# casual           0
# registered       0
# cnt              0
# dtype: int64

# %%
merged_df
# Out:
#         dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0   2011-01-29       1   0     1   1      NaN        6           1  0.22
# 1   2011-01-29       1   0     1   2      NaN        6           1  0.22
# 2   2011-01-29       1   0     1   3      NaN        6           1  0.20
# 3   2011-01-29       1   0     1   4      NaN        6           1  0.16
# 4   2011-01-29       1   0     1   6      NaN        6           1  0.16
# ..         ...     ...  ..   ...  ..      ...      ...         ...   ...
# 995 2011-01-28       1   0     1  11      NaN        5           3  0.18
# 996 2011-01-28       1   0     1  12      NaN        5           3  0.18
# 997 2011-01-28       1   0     1  13      NaN        5           3  0.18
# 998 2011-01-28       1   0     1  14      NaN        5           3  0.22
# 999 2011-01-28       1   0     1  15      NaN        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
print(merged_df.dtypes)
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday              float64
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
merged_df.drop('holiday', axis=1, inplace=True)

# %%
merged_df
# Out:
#         dteday  season  yr  mnth  hr  weekday  weathersit  temp   atemp   hum  \
# 0   2011-01-29       1   0     1   1        6           1  0.22  0.2273  0.64
# 1   2011-01-29       1   0     1   2        6           1  0.22  0.2273  0.64
# 2   2011-01-29       1   0     1   3        6           1  0.20  0.2121  0.64
# 3   2011-01-29       1   0     1   4        6           1  0.16  0.1818  0.69
# 4   2011-01-29       1   0     1   6        6           1  0.16  0.1818  0.64
# ..         ...     ...  ..   ...  ..      ...         ...   ...     ...   ...
# 995 2011-01-28       1   0     1  11        5           3  0.18  0.2121  0.93
# 996 2011-01-28       1   0     1  12        5           3  0.18  0.2121  0.93
# 997 2011-01-28       1   0     1  13        5           3  0.18  0.2121  0.93
# 998 2011-01-28       1   0     1  14        5           3  0.22  0.2727  0.80
# 999 2011-01-28       1   0     1  15        5           2  0.20  0.2576  0.86
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import boxcox
from sklearn.preprocessing import PowerTransformer

# Example: Find numeric columns
numeric_cols = merged_df.select_dtypes(include=[np.number]).columns

# Check skewness
skewness = merged_df[numeric_cols].skew()
print(skewness)

# Apply transformation to reduce skewness:
# Option 1: Log transformation (for positive values)
for col in numeric_cols:
    if (merged_df[col] > 0).all():
        merged_df[col + '_log'] = np.log1p(merged_df[col])

# Option 2: Box-Cox transformation (for positive values)
for col in numeric_cols:
    if (merged_df[col] > 0).all():
        merged_df[col + '_boxcox'], _ = boxcox(merged_df[col])

# Option 3: Yeo-Johnson transformation (works with positive and negative values)
pt = PowerTransformer(method='yeo-johnson')
merged_df[numeric_cols] = pt.fit_transform(merged_df[numeric_cols])

# Check skewness after transformation
print(merged_df[numeric_cols].skew())
# Out:
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# atemp         0.435927
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 22
#      20 for col in numeric_cols:
#      21     if (merged_df[col] > 0).all():
# ---> 22         merged_df[col + '_boxcox'], _ = boxcox(merged_df[col])
#      24 # Option 3: Yeo-Johnson transformation (works with positive and negative values)
#      25 pt = PowerTransformer(method='yeo-johnson')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1114, in boxcox(x, lmbda, alpha, optimizer)
#    1111     return x
#    1113 if np.all(x == x[0]):
# ...
